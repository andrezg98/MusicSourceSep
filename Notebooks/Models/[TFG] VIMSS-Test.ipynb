# %% [markdown]
# # **VIMSS Visually-Informed Music Source Separation - Repository**
# Clonamos el repositorio desde GitHub

# %%
# !git clone https://github.com/Veleslavia/vimss
# Out:
# Cloning into 'vimss'...
# remote: Enumerating objects: 886, done.
# remote: Total 886 (delta 0), reused 0 (delta 0), pack-reused 886
# Receiving objects: 100% (886/886), 13.65 MiB | 14.91 MiB/s, done.
# Resolving deltas: 100% (643/643), done.

# %%
# Accedemos a mi drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Requirements
# !pip3 install -r /content/vimss/requirements.txt

# %%
# Utils
# !python3 "/content/vimss/Utils.py"
# Out:
# 2021-03-14 12:58:30.502669: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# ##**Training**

# %%
# !pip3 install tensorflow==1.15.2
# Out:
# ...
#      |████████████████████████████████| 110.5MB 44kB/s
# ...
#      |████████████████████████████████| 512kB 40.9MB/s
# ...
#      |████████████████████████████████| 3.8MB 44.0MB/s
# ...
#      |████████████████████████████████| 51kB 6.9MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp37-none-any.whl size=7540 sha256=918342c83a37b531ca3582b5f045ce89f77d6bcf7c8a37c07865e9aece369d37
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.12.1 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ...
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
#   Found existing installation: gast 0.3.3
# ...

# %%
# !python3 /content/vimss/Training.py
# Out:
# WARNING - Conditioned-Waveunet - No observers have been added to this run
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/sacred/randomness.py:34: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING - tensorflow - From /usr/local/lib/python3.7/dist-packages/sacred/randomness.py:34: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# INFO - Conditioned-Waveunet - Running command 'experiment'
# INFO - Conditioned-Waveunet - Started
# WARNING:tensorflow:From /content/vimss/Training.py:274: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING - tensorflow - From /content/vimss/Training.py:274: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# ...

# %% [markdown]
# ##**Test**

# %% [markdown]
# ##**Evaluate**
