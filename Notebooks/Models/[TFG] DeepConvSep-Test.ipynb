# %% [markdown]
# # **DeepConvSep - Repository**
# Clonamos el repositorio desde GitHub

# %%
# !git clone https://github.com/MTG/DeepConvSep.git
# Out:
# Cloning into 'DeepConvSep'...
# remote: Enumerating objects: 493, done.
# remote: Total 493 (delta 0), reused 0 (delta 0), pack-reused 493
# Receiving objects: 100% (493/493), 37.15 MiB | 15.98 MiB/s, done.
# Resolving deltas: 100% (284/284), done.

# %%
# Accedemos a mi drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Bach10 - Dataset

# %%
# !unzip "drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Datasets/Bach10/Bach10.zip"

# %% [markdown]
# ### Bach10 Sibeluis - Dataset

# %%
# !tar -zxvf "drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Datasets/Bach10/Bach10 Sibelius.tar.gz"

# %% [markdown]
# ### Dsd100 - Dataset

# %%
# !pip install dsdtools

# %%
# !unzip "drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Datasets/dsd100-Dataset/DSD100subset.zip"

# %% [markdown]
# ## 1. Extraer caracteristicas `compute_features`

# %% [markdown]
# ### Bach10 folder (bassoon, clarinet, saxophone, violin)

# %%
# !cp /content/DeepConvSep/examples/bach10/compute_features_bach10.py /content/DeepConvSep

# %%
# !mkdir DeepConvSep/features

# %%
# !python2 "/content/DeepConvSep/compute_features_bach10.py" --db "/content/Bach10_v1.1" --feature_path "/content/DeepConvSep/features"

# %% [markdown]
# ### Bach10_scoreinformed folder (rwc)

# %% [markdown]
# El dataset RWC es difícil de conseguir, porque hay que enviar un formulario y pagar :(

# %%
# !cp /content/DeepConvSep/examples/bach10_scoreinformed/compute_features_bach10rwc.py /content/DeepConvSep

# %%
# !mkdir DeepConvSep/features_scoreinformed

# %%
# !python2 "/content/DeepConvSep/compute_features_bach10rwc.py" --db "/content/Bach10 Sibelius" --rwc --feature_path "/content/DeepConvSep/features_scoreinformed"

# %% [markdown]
# ### Dsd100 folder (vocals, bass, drums, accompaniment)

# %%
# !cp /content/DeepConvSep/examples/dsd100/compute_features.py /content/DeepConvSep

# %%
# !mkdir DeepConvSep/features_dsd

# %%
# !python2 "/content/DeepConvSep/compute_features.py" --db "/content/DSD100subset" --feature_path "/content/DeepConvSep/features_dsd"
# Out:
# /usr/local/lib/python2.7/dist-packages/scipy/io/wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)

# %% [markdown]
# ## 2. Entrenar modelo usando las caracteristicas con `trainCNN`

# %%
# !python2 -m pip install --upgrade https://github.com/Lasagne/Lasagne/archive/master.zip

# %%
# !python2 -m pip install --upgrade theano

# %% [markdown]
# ### Bach10 folder (bassoon, clarinet, saxophone, violin)

# %%
# !cp /content/DeepConvSep/examples/bach10/trainCNNbach10.py /content/DeepConvSep

# %%
# !mkdir DeepConvSep/train_out

# %%
# !python2 "/content/DeepConvSep/trainCNNbach10.py" --db "/content/Bach10_v1.1" --dbs "/content/Bach10 Sibelius" --output "/content/DeepConvSep/train_out" --feature_path "/content/DeepConvSep/features"

# %% [markdown]
# ### Dsd100 folder (vocals, bass, drums, accompaniment)

# %%
# !cp /content/DeepConvSep/examples/dsd100/trainCNN.py /content/DeepConvSep

# %%
# !mkdir DeepConvSep/train_out_dsd

# %%
# !python2 "/content/DeepConvSep/trainCNN.py" --db "/content/DSD100subset/" --feature_path "/content/DeepConvSep/features_dsd"

# %% [markdown]
# ## 3. Usar ese modelo generado para llamar al script `separate`

# %% [markdown]
# ### Bach10 folder (bassoon, clarinet, saxophone, violin)

# %%
# !cp /content/DeepConvSep/examples/bach10/separate_bach10.py /content/DeepConvSep

# %%
# !mkdir DeepConvSep/separate_out

# %%
# He utilizado un modelo ya entrenado porque no me funciona el entrenamiento
# !python2 "/content/DeepConvSep/separate_bach10.py" -i "/content/Bach10_v1.1/01-AchGottundHerr/01-AchGottundHerr.wav" -o "/content/DeepConvSep/separate_out" -m "/content/drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Tools/DeepConvSep_Model/model_fft_rwc_synth_one_aug_more_4096_blind_nomp_all.pkl"

# %%
# Reproducción audio completo
import IPython.display as ipd
ipd.Audio('/content/Bach10_v1.1/01-AchGottundHerr/01-AchGottundHerr.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Reproducción audio saxo separado
ipd.Audio('/content/DeepConvSep/separate_out_dsd/01-AchGottundHerr_saxphone.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Dsd100 folder (vocals, bass, drums, accompaniment)

# %%
# !cp /content/DeepConvSep/examples/dsd100/separate_dsd.py /content/DeepConvSep

# %%
# !mkdir DeepConvSep/separate_out_dsd

# %%
# Utilizamos el modelo entrenado
# !python2 "/content/DeepConvSep/separate_dsd.py" -i "/content/DSD100subset/Mixtures/Test/005 - Angela Thomas Wade - Milk Cow Blues/mixture.wav" -o "/content/DeepConvSep/separate_out_dsd" -m "/content/DSD100subset/models/model_dsd_fft_1024.pkl"

# %%
# Reproducción audio completo
import IPython.display as ipd
ipd.Audio('/content/DSD100subset/Mixtures/Test/005 - Angela Thomas Wade - Milk Cow Blues/mixture.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Reproducción audio vocals separado
ipd.Audio('/content/DeepConvSep/separate_out_dsd/vocals.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## 4. Prueba con el **URMP - Dataset**

# %% [markdown]
# A partir del modelo entrenado con Bach10

# %% [markdown]
# *Flauta y Violín*

# %%
# !python2 -m pip install pysoundfile

# %%
import soundfile

data, samplerate = soundfile.read('/content/drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Datasets/URMP-Dataset/08_Spring_fl_vn/AuMix_08_Spring_fl_vn.wav')
soundfile.write('/content/drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Datasets/URMP-Dataset/08_Spring_fl_vn/AuMix_08_Spring_fl_vn.wav', data, samplerate, subtype='PCM_16')

# %%
# !mkdir DeepConvSep/URMPseparate_out

# %%
# !python2 "/content/DeepConvSep/separate_bach10.py" -i "/content/drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Datasets/URMP-Dataset/08_Spring_fl_vn/AuMix_08_Spring_fl_vn.wav" -o "/content/DeepConvSep/URMPseparate_out" -m "/content/drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Tools/DeepConvSep_Model/model_fft_rwc_synth_one_aug_more_4096_blind_nomp_all.pkl"
# Out:
# WARNING (theano.tensor.blas): We did not find a dynamic library in the library_dir of the library we use for blas. If you use ATLAS, make sure to compile it with dynamics library.

# %%
# Reproducción audio completo
import IPython.display as ipd
ipd.Audio('/content/drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Datasets/URMP-Dataset/08_Spring_fl_vn/AuMix_08_Spring_fl_vn.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Reproducción audio violín separado
ipd.Audio('/content/DeepConvSep/URMPseparate_out/AuMix_08_Spring_fl_vn_violin.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# En este ejemplo podemos ver que los instrumentos de partida son flauta y violín. Dado que el modelo entrenado de Bach10 se entrena para separar archivos en fagot, saxo, clarinete y violín; cuando probamos con nuestro archivo, la separación que realiza de la fuente de audio "violín" es bastante buena.

# %%
# Reproducción audio flauta separado
ipd.Audio('/content/DeepConvSep/URMPseparate_out/AuMix_08_Spring_fl_vn_clarinet.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Reproducción audio flauta separado
ipd.Audio('/content/DeepConvSep/URMPseparate_out/AuMix_08_Spring_fl_vn_saxphone.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Reproducción audio flauta separado
ipd.Audio('/content/DeepConvSep/URMPseparate_out/AuMix_08_Spring_fl_vn_bassoon.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# En este otro caso, para diferenciar la fuente "flauta" podríamos quedarnos con las fuentes separadas de viento del clarinete, el saxofón y el fagot, donde podemos comprobar que el modelo separa en diferentes archivos en función del registro de cada instrumento. Similar a filtrar las frecuencias en registros agudos, medios o graves de los instrumentos de viento que no reconoce.

# %% [markdown]
# *Clarinete, saxo y tuba*

# %%
import soundfile

data, samplerate = soundfile.read('/content/drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Datasets/URMP-Dataset/23_Rejouissance_cl_sax_tba/AuMix_23_Rejouissance_cl_sax_tba.wav')
soundfile.write('/content/drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Datasets/URMP-Dataset/23_Rejouissance_cl_sax_tba/AuMix_23_Rejouissance_cl_sax_tba.wav', data, samplerate=44100, subtype='PCM_16')

# %%
# !mkdir DeepConvSep/URMPseparate_out2

# %%
# !python2 "/content/DeepConvSep/separate_bach10.py" -i "/content/drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Datasets/URMP-Dataset/23_Rejouissance_cl_sax_tba/AuMix_23_Rejouissance_cl_sax_tba.wav" -o "/content/DeepConvSep/URMPseparate_out2" -m "/content/drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Tools/DeepConvSep_Model/model_fft_rwc_synth_one_aug_more_4096_blind_nomp_all.pkl"
# Out:
# WARNING (theano.tensor.blas): We did not find a dynamic library in the library_dir of the library we use for blas. If you use ATLAS, make sure to compile it with dynamics library.
# tcmalloc: large alloc 2832539648 bytes == 0x55fd2be3c000 @  0x7f7df97591e7 0x7f7df75b1771 0x7f7df761628e 0x7f7df76198e0 0x7f7df7619e85 0x7f7df76b2bdd 0x55fb5b2137ca 0x55fb5b210e0a 0x55fb5b21892e 0x55fb5b218556 0x55fb5b210e0a 0x55fb5b210879 0x55fb5b240f5f 0x55fb5b23c222 0x55fb5b23bc4d 0x55fb5b1eaa86 0x7f7df9356bf7 0x55fb5b1ea37a

# %%
# Reproducción audio completo
import IPython.display as ipd
ipd.Audio('/content/drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Datasets/URMP-Dataset/23_Rejouissance_cl_sax_tba/AuMix_23_Rejouissance_cl_sax_tba.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Reproducción audio clarinete separado
ipd.Audio('/content/DeepConvSep/URMPseparate_out2/AuMix_23_Rejouissance_cl_sax_tba_clarinet.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Reproducción audio saxo separado
ipd.Audio('/content/DeepConvSep/URMPseparate_out2/AuMix_23_Rejouissance_cl_sax_tba_saxphone.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Reproducción audio tuba separado
ipd.Audio('/content/DeepConvSep/URMPseparate_out2/AuMix_23_Rejouissance_cl_sax_tba_bassoon.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# *Violín y Cello*

# %%
import soundfile

data, samplerate = soundfile.read('/content/drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Datasets/URMP-Dataset/01_Jupiter_vn_vc/AuMix_01_Jupiter_vn_vc.wav')
soundfile.write('/content/drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Datasets/URMP-Dataset/01_Jupiter_vn_vc/AuMix_01_Jupiter_vn_vc.wav', data, samplerate=44100, subtype='PCM_16')

# %%
# !mkdir DeepConvSep/URMPseparate_out3

# %%
# !python2 "/content/DeepConvSep/separate_bach10.py" -i "/content/drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Datasets/URMP-Dataset/01_Jupiter_vn_vc/AuMix_01_Jupiter_vn_vc.wav" -o "/content/DeepConvSep/URMPseparate_out3" -m "/content/drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Tools/DeepConvSep_Model/model_fft_rwc_synth_one_aug_more_4096_blind_nomp_all.pkl"
# Out:
# WARNING (theano.tensor.blas): We did not find a dynamic library in the library_dir of the library we use for blas. If you use ATLAS, make sure to compile it with dynamics library.
# tcmalloc: large alloc 2328977408 bytes == 0x5603402b6000 @  0x7fbf3b0c71e7 0x7fbf38f1f771 0x7fbf38f8428e 0x7fbf38f878e0 0x7fbf38f87e85 0x7fbf39020bdd 0x5601aed4d7ca 0x5601aed4ae0a 0x5601aed5292e 0x5601aed52556 0x5601aed4ae0a 0x5601aed4a879 0x5601aed7af5f 0x5601aed76222 0x5601aed75c4d 0x5601aed24a86 0x7fbf3acc4bf7 0x5601aed2437a

# %%
# Reproducción audio completo
import IPython.display as ipd
ipd.Audio('/content/drive/MyDrive/ING. SONIDO E IMAGEN/TFG/Datasets/URMP-Dataset/01_Jupiter_vn_vc/AuMix_01_Jupiter_vn_vc.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Reproducción audio violín separado
ipd.Audio('/content/DeepConvSep/URMPseparate_out3/AuMix_01_Jupiter_vn_vc_violin.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Reproducción audio cello separado
ipd.Audio('/content/DeepConvSep/URMPseparate_out3/AuMix_01_Jupiter_vn_vc_bassoon.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# En vista de los resultados, no podemos decir que realice una buena separación para los datos del URMP Dataset
